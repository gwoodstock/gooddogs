# %%
import pandas as pd
import numpy as np
import missingno as mn

# %%
breed_stats = pd.read_csv('./datasets/breeds_info_clean.csv')

# %%
breed_stats.head(3)
# Out:
#              breed  classification  obey  reps_lower  reps_upper  \
# 0    border collie  brightest dogs  0.95         1.0         4.0
# 1           poodle  brightest dogs  0.95         1.0         4.0
# 2  german shepherd  brightest dogs  0.95         1.0         4.0
#
#    height_low_inches  height_high_inches  weight_low_lbs  weight_high_lbs
# 0               19.0                21.0            40.0             40.0
# 1                NaN                 NaN             NaN              NaN
# 2               22.0                26.0            75.0             90.0

# %%
breeds = set(breed_stats['breed'])

# %%
shelter = pd.read_csv('./datasets/cleaned_data/texas_shelters_breeds_cleaned.csv')
# Out:
# /Users/genebob/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (3,9,11,18,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
shelter.head(3)
# Out:
#    Unnamed: 0       id                        breed        color  \
# 0           0  A047759                    dachshund     Tricolor
# 1           1  A134067            shetland sheepdog  Brown/White
# 2           2  A141142  labrador retriever/pit bull  Black/White
#
#             dob  sex       date_in  age_in  intact_in  \
# 0  1.080864e+09  1.0  1.396454e+09    10.0        0.0
# 1  8.769600e+08  1.0  1.384593e+09    16.0        0.0
# 2  8.966592e+08  0.0  1.384613e+09    15.0        0.0
#
#                              location  ...      date_out age_out intact_out  \
# 0                         Austin (TX)  ...  1.396884e+09    10.0        0.0
# 1  12034 Research Blvd in Austin (TX)  ...  1.384603e+09    16.0        0.0
# 2                         Austin (TX)  ...  1.384688e+09    15.0        0.0
#
#         outcome     age  primary_color secondary_color             breed_1  \
# 0      transfer  Senior       Tricolor        Tricolor           dachshund
# 1  owner_return  Senior          Brown           White   shetland sheepdog
# 2  owner_return  Senior          Black           White  labrador retriever
#
#              breed_2 pure
# 0          dachshund  1.0
# 1  shetland sheepdog  1.0
# 2           pit bull  NaN
#
# [3 rows x 23 columns]

# %%
shelter.columns
# Out:
# Index(['Unnamed: 0', 'id', 'breed', 'color', 'dob', 'sex', 'date_in', 'age_in',
#        'intact_in', 'location', 'intake_type', 'intake_subtype', 'condition',
#        'date_out', 'age_out', 'intact_out', 'outcome', 'age', 'primary_color',
#        'secondary_color', 'breed_1', 'breed_2', 'pure'],
#       dtype='object')

# %%
shelter.drop(columns=['Unnamed: 0', 'id', 'color', 'dob', 'age_in', 'intact_in', 'location', 'intake_subtype'])
# Out:
#                               breed  sex       date_in    intake_type  \
# 0                         dachshund  1.0  1.396454e+09      surrender
# 1                 shetland sheepdog  1.0  1.384593e+09  public_assist
# 2       labrador retriever/pit bull  0.0  1.384613e+09          stray
# 3               miniature schnauzer  0.0  1.415978e+09          stray
# 4                        lhasa apso  1.0  1.410780e+09          stray
# ...                             ...  ...           ...            ...
# 132613                    chihuahua  NaN  1.576541e+09          stray
# 132614                    chihuahua  NaN  1.576541e+09          stray
# 132615               french bulldog  NaN  1.576541e+09          stray
# 132616                      bulldog  NaN  1.576541e+09          stray
# 132617                     pit bull  NaN  1.576541e+09          stray
#
#        condition      date_out  age_out  intact_out       outcome     age  \
# 0            wnl  1.396884e+09     10.0         0.0      transfer  Senior
# 1       med_attn  1.384603e+09     16.0         0.0  owner_return  Senior
# 2           aged  1.384688e+09     15.0         0.0  owner_return  Senior
# 3            wnl  1.415993e+09     15.0         1.0  owner_return  Senior
# 4            wnl  1.410799e+09     15.0         0.0  owner_return  Senior
# ...          ...           ...      ...         ...           ...     ...
# 132613     other           NaN      NaN         NaN  owner_return   Adult
# 132614       wnl           NaN      NaN         NaN  owner_return   Adult
# 132615     other           NaN      NaN         NaN  owner_return   Adult
# 132616       wnl           NaN      NaN         NaN  owner_return   Adult
# 132617       wnl           NaN      NaN         NaN  owner_return   Adult
#
#        primary_color secondary_color              breed_1  \
# 0           Tricolor        Tricolor            dachshund
# 1              Brown           White    shetland sheepdog
# 2              Black           White   labrador retriever
# 3              Black            Gray  miniature schnauzer
# 4              Brown           White           lhasa apso
# ...              ...             ...                  ...
# 132613           NaN             NaN            chihuahua
# 132614           NaN             NaN            chihuahua
# 132615           NaN             NaN       french bulldog
# 132616           NaN             NaN              bulldog
# 132617           NaN             NaN             pit bull
#
#                     breed_2  pure
# 0                 dachshund   1.0
# 1         shetland sheepdog   1.0
# 2                  pit bull   NaN
# 3       miniature schnauzer   1.0
# 4                lhasa apso   1.0
# ...                     ...   ...
# 132613            chihuahua   1.0
# 132614            chihuahua   1.0
# 132615       french bulldog   1.0
# 132616              bulldog   1.0
# 132617             pit bull   1.0
#
# [132618 rows x 15 columns]

# %%
shelter['pure'].fillna(0, inplace=True)

# %%
mn.matrix(shelter)
# Out:
# <AxesSubplot:>

# %%
breed_stats.columns
# Out:
# Index(['breed', 'classification', 'obey', 'reps_lower', 'reps_upper',
#        'height_low_inches', 'height_high_inches', 'weight_low_lbs',
#        'weight_high_lbs'],
#       dtype='object')

# %%
breed_stats.set_index('breed')
# Out:
#                              classification  obey  reps_lower  reps_upper  \
# breed
# border collie                brightest dogs  0.95         1.0         4.0
# poodle                       brightest dogs  0.95         1.0         4.0
# german shepherd              brightest dogs  0.95         1.0         4.0
# golden retriever             brightest dogs  0.95         1.0         4.0
# doberman pinscher            brightest dogs  0.95         1.0         4.0
# ...                                     ...   ...         ...         ...
# miniature poodle                        NaN   NaN         NaN         NaN
# shetland sheepdog (sheltie)             NaN   NaN         NaN         NaN
# silky terrier                           NaN   NaN         NaN         NaN
# toy poodle                              NaN   NaN         NaN         NaN
# toy fox terrier                         NaN   NaN         NaN         NaN
#
#                              height_low_inches  height_high_inches  \
# breed
# border collie                             19.0                21.0
# poodle                                     NaN                 NaN
# german shepherd                           22.0                26.0
# golden retriever                          21.0                24.0
# doberman pinscher                         26.0                28.0
# ...                                        ...                 ...
# miniature poodle                          10.0                15.0
# shetland sheepdog (sheltie)               13.0                16.0
# silky terrier                              9.0                10.0
# toy poodle                                10.0                10.0
# toy fox terrier                           10.0                10.0
#
#                              weight_low_lbs  weight_high_lbs
# breed
# border collie                          40.0             40.0
# poodle                                  NaN              NaN
# german shepherd                        75.0             90.0
# golden retriever                       55.0             75.0
# doberman pinscher                      60.0            100.0
# ...                                     ...              ...
# miniature poodle                       20.0             20.0
# shetland sheepdog (sheltie)            14.0             20.0
# silky terrier                           8.0             11.0
# toy poodle                             10.0             10.0
# toy fox terrier                         4.0              7.0
#
# [168 rows x 8 columns]

# %%
def gen_breed_stats(x):
    if x in breeds:
        stats = breed_stats
        return stats.set_index('breed').loc[x,:]

# %%
gen_breed_stats('poodle')
# Out:
# classification        brightest dogs
# obey                            0.95
# reps_lower                       1.0
# reps_upper                       4.0
# height_low_inches                NaN
# height_high_inches               NaN
# weight_low_lbs                   NaN
# weight_high_lbs                  NaN
# Name: poodle, dtype: object
