# %%
import pandas as pd

# %% [markdown]
# # Read in data

# %%
austin_intakes = pd.read_csv('/Users/annarutledge/Documents/general_assembly/project4/datasets/texas_dogs/austin_animal_center_intakes.csv')

# %%
austin_intakes.head(2)
# Out:
#   Animal ID    Name                DateTime     MonthYear  \
# 0   A786884  *Brock  01/03/2019 04:19:00 PM  January 2019
# 1   A706918   Belle  07/05/2015 12:59:00 PM     July 2015
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake                     Breed  \
# 0         Dog   Neutered Male         2 years                Beagle Mix
# 1         Dog   Spayed Female         8 years  English Springer Spaniel
#
#          Color
# 0     Tricolor
# 1  White/Liver

# %%
austin_outcomes = pd.read_csv('/Users/annarutledge/Documents/general_assembly/project4/datasets/texas_dogs/austin_animal_center_outcomes.csv')

# %%
austin_outcomes.head(2)
# Out:
#   Animal ID   Name                DateTime MonthYear Date of Birth  \
# 0   A794011  Chunk  05/08/2019 06:20:00 PM  May 2019    05/02/2017
# 1   A776359  Gizmo  07/18/2018 04:02:00 PM  Jul 2018    07/12/2017
#
#   Outcome Type Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0    Rto-Adopt             NaN         Cat    Neutered Male          2 years
# 1     Adoption             NaN         Dog    Neutered Male           1 year
#
#                      Breed              Color
# 0   Domestic Shorthair Mix  Brown Tabby/White
# 1  Chihuahua Shorthair Mix        White/Brown

# %%
austin_outcomes_2 = pd.read_csv('/Users/annarutledge/Documents/general_assembly/project4/datasets/texas_dogs/austin_animal_center_outcomes_2.csv')

# %%
austin_outcomes_2.head(2)
# Out:
#   Animal ID   Name                DateTime MonthYear Date of Birth  \
# 0   A794011  Chunk  05/08/2019 06:20:00 PM  May 2019    05/02/2017
# 1   A776359  Gizmo  07/18/2018 04:02:00 PM  Jul 2018    07/12/2017
#
#   Outcome Type Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0    Rto-Adopt             NaN         Cat    Neutered Male          2 years
# 1     Adoption             NaN         Dog    Neutered Male           1 year
#
#                      Breed              Color
# 0   Domestic Shorthair Mix  Brown Tabby/White
# 1  Chihuahua Shorthair Mix        White/Brown

# %%
austin_animal_data = pd.read_csv('/Users/annarutledge/Documents/general_assembly/project4/datasets/texas_dogs/austin_animal_data.csv')

# %%
austin_animal_data.head(2)
# Out:
#       id     intakedate intakereason  istransfer sheltercode identichipnumber  \
# 0  15801  11/28/09 0:00       Moving           0   C09115463       0A115D7358
# 1  15932   12/8/09 0:00       Moving           0   D09125594       0A11675477
#
#   animalname                breedname basecolour speciesname  ...  \
# 0     Jadzia      Domestic Short Hair     Tortie         Cat  ...
# 1      Gonzo  German Shepherd Dog/Mix        Tan         Dog  ...
#
#    movementdate movementtype istrial returndate returnedreason  deceaseddate  \
# 0  5/13/17 0:00     Adoption     0.0        NaN          Stray           NaN
# 1  4/24/17 0:00     Adoption     0.0        NaN          Stray           NaN
#
#   deceasedreason diedoffshelter puttosleep isdoa
# 0   Died in care              0          0     0
# 1   Died in care              0          0     0
#
# [2 rows x 23 columns]

# %%
dallas_shelter_data = pd.read_csv('/Users/annarutledge/Documents/general_assembly/project4/datasets/texas_dogs/dallas_animal_shelter_data.csv')

# %%
dallas_shelter_data.head(2)
# Out:
#   Animal Id Animal Type Animal Breed Kennel Number Kennel Status  Tag Type  \
# 0  A1093136         CAT  DOMESTIC SH           K01     IMPOUNDED       NaN
# 1  A1046046         DOG     PIT BULL        AD 085   UNAVAILABLE       NaN
#
#   Activity Number  Activity Sequence Source Id Census Tract  ... Outcome Time  \
# 0             NaN                  1  P0915082         5200  ...     14:46:00
# 1      A19-203263                  1  P0740141        12900  ...     14:56:00
#
#   Receipt Number Impound Number  Service Request Number Outcome Condition  \
# 0            NaN     K20-494003                     NaN          APP SICK
# 1     R19-561166     K19-489088                     NaN           APP WNL
#
#     Chip Status     Animal Origin Additional Information     Month    Year
# 0  SCAN NO CHIP  OVER THE COUNTER                    NaN  JAN.2020  FY2020
# 1     SCAN CHIP             FIELD               ADOPTION  NOV.2019  FY2020
#
# [2 rows x 34 columns]

# %% [markdown]
# # Filter datasets to only include dogs

# %% [markdown]
# ## austin_intakes

# %%
# Animal types other than dogs in austin_intakes

austin_intakes[austin_intakes['Animal Type']!='Dog']['Animal Type'].unique()
# Out:
# array(['Cat', 'Other', 'Bird', 'Livestock'], dtype=object)

# %%
austin_intakes[austin_intakes['Animal Type']!='Dog']
# Out:
#        Animal ID      Name                DateTime      MonthYear  \
# 3        A665644       NaN  10/21/2013 07:59:00 AM   October 2013
# 7        A844350     *Ella  10/15/2021 11:40:00 AM   October 2021
# 9        A818975       NaN  06/18/2020 02:53:00 PM      June 2020
# 10       A774147       NaN  06/11/2018 07:45:00 AM      June 2018
# 11       A731435    *Casey  08/08/2016 05:52:00 PM    August 2016
# ...          ...       ...                     ...            ...
# 136276   A851251   A851251  02/09/2022 09:09:00 AM  February 2022
# 136279   A851273   A851273  02/09/2022 12:27:00 PM  February 2022
# 136281   A851268       NaN  02/09/2022 11:21:00 AM  February 2022
# 136284   A851279  Whiskers  02/09/2022 02:16:00 PM  February 2022
# 136286   A851280     Gemma  02/09/2022 02:16:00 PM  February 2022
#
#                                        Found Location      Intake Type  \
# 3                                         Austin (TX)            Stray
# ...

# %%
#Indexes of rows with animal types other than 'Dog' in austin_intakes

austin_intakes[austin_intakes['Animal Type']!='Dog'].index
# Out:
# Int64Index([     3,      7,      9,     10,     11,     15,     16,     17,
#                 18,     19,
#             ...
#             136230, 136237, 136261, 136265, 136272, 136276, 136279, 136281,
#             136284, 136286],
#            dtype='int64', length=59519)

# %%
#Drop rows with animal type other than 'Dog' to create new df with dogs only

austin_intakes_dogs = austin_intakes.drop(labels=austin_intakes[austin_intakes['Animal Type']!='Dog'].index)

# %%
#check that df only contains dogs

austin_intakes_dogs['Animal Type'].unique()
# Out:
# array(['Dog'], dtype=object)

# %% [markdown]
# ## austin_outcomes

# %% [markdown]
# #### Merge austin_outcomes and austin_outcomes2

# %%
austin_outcomes.tail(10)
# Out:
#        Animal ID         Name                DateTime MonthYear Date of Birth  \
# 136528   A851114          NaN  02/09/2022 03:32:00 PM  Feb 2022    02/06/2021
# 136529   A847853       Kitchi  02/09/2022 04:00:00 PM  Feb 2022    12/09/2019
# 136530   A850992        *Gwen  02/09/2022 03:59:00 PM  Feb 2022    02/03/2014
# 136531   A847741      Phantom  02/09/2022 03:08:00 PM  Feb 2022    09/22/2021
# 136532   A850605         Hank  02/02/2022 03:54:00 PM  Feb 2022    11/27/2021
# 136533   A850751  *Goldenbear  02/09/2022 03:54:00 PM  Feb 2022    01/31/2014
# 136534   A850868        *Dora  02/09/2022 03:37:00 PM  Feb 2022    02/01/2020
# 136535   A850958         Ryuk  02/09/2022 03:58:00 PM  Feb 2022    06/02/2021
# 136536   A848401      *George  02/09/2022 03:55:00 PM  Feb 2022    06/20/2021
# 136537   A850956      A850956  02/09/2022 03:41:00 PM  Feb 2022    12/02/2021
#
#        Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# ...

# %%
austin_outcomes_2.tail(40)
# Out:
#        Animal ID                 Name                DateTime MonthYear  \
# 136530   A847897                 Spot  02/09/2022 04:55:00 PM  Feb 2022
# 136531   A850553          *Snow White  02/09/2022 03:30:00 PM  Feb 2022
# 136532   A850904            *Rasputin  02/09/2022 04:51:00 PM  Feb 2022
# 136533   A850548          *Thumbelina  02/09/2022 03:30:00 PM  Feb 2022
# 136534   A851218                 Suzy  02/09/2022 04:25:00 PM  Feb 2022
# 136535   A850774                Jayco  02/09/2022 04:03:00 PM  Feb 2022
# 136536   A850643             *Estella  02/09/2022 04:45:00 PM  Feb 2022
# 136537   A764603                 Luna  02/09/2022 04:01:00 PM  Feb 2022
# 136538   A850556            *Rapunzel  02/09/2022 03:30:00 PM  Feb 2022
# 136539   A850905                *Ivan  02/09/2022 04:58:00 PM  Feb 2022
# 136540   A850555     *Rumplestiltskin  02/09/2022 03:30:00 PM  Feb 2022
# 136541   A850554            *Rose Red  02/09/2022 03:30:00 PM  Feb 2022
# ...

# %%
austin_outcomes.shape
# Out:
# (136538, 12)

# %%
austin_outcomes_2.shape
# Out:
# (136570, 12)

# %%
# create dataframe to check what rows are present in both austin_outcomes and austin_outcomes_2 and which are unique

comparison_df = austin_outcomes_2.merge(
        austin_outcomes,
        indicator=True,
        how='outer')

#(code borrowed from https://hackersandslackers.com/compare-rows-pandas-dataframes/)

# %%
comparison_df.head()
# Out:
#   Animal ID   Name                DateTime MonthYear Date of Birth  \
# 0   A794011  Chunk  05/08/2019 06:20:00 PM  May 2019    05/02/2017
# 1   A776359  Gizmo  07/18/2018 04:02:00 PM  Jul 2018    07/12/2017
# 2   A821648    NaN  08/16/2020 11:38:00 AM  Aug 2020    08/16/2019
# 3   A720371  Moose  02/13/2016 05:59:00 PM  Feb 2016    10/08/2015
# 4   A674754    NaN  03/18/2014 11:47:00 AM  Mar 2014    03/12/2014
#
#   Outcome Type Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0    Rto-Adopt             NaN         Cat    Neutered Male          2 years
# 1     Adoption             NaN         Dog    Neutered Male           1 year
# 2   Euthanasia             NaN       Other          Unknown           1 year
# 3     Adoption             NaN         Dog    Neutered Male         4 months
# 4     Transfer         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color _merge
# ...

# %%
# 54 rows present in only one of the two dataframes

comparison_df[comparison_df['_merge']!='both'].shape
# Out:
# (54, 13)

# %%
# merge dataframes

pd.concat([austin_outcomes, austin_outcomes_2]).shape
# Out:
# (273108, 12)

# %%
austin_outcomes_merged = pd.concat([austin_outcomes, austin_outcomes_2])

# %%
# drop duplicated rows

austin_outcomes_merged.drop_duplicates(keep='first').shape
# Out:
# (136564, 12)

# %%
austin_outcomes_merged.drop_duplicates(keep='first', inplace=True)

# %%
austin_outcomes_merged.head()
# Out:
#   Animal ID   Name                DateTime MonthYear Date of Birth  \
# 0   A794011  Chunk  05/08/2019 06:20:00 PM  May 2019    05/02/2017
# 1   A776359  Gizmo  07/18/2018 04:02:00 PM  Jul 2018    07/12/2017
# 2   A821648    NaN  08/16/2020 11:38:00 AM  Aug 2020    08/16/2019
# 3   A720371  Moose  02/13/2016 05:59:00 PM  Feb 2016    10/08/2015
# 4   A674754    NaN  03/18/2014 11:47:00 AM  Mar 2014    03/12/2014
#
#   Outcome Type Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0    Rto-Adopt             NaN         Cat    Neutered Male          2 years
# 1     Adoption             NaN         Dog    Neutered Male           1 year
# 2   Euthanasia             NaN       Other          Unknown           1 year
# 3     Adoption             NaN         Dog    Neutered Male         4 months
# 4     Transfer         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color
# ...

# %% [markdown]
# #### Filter austin_outcomes_merged to only include dogs

# %%
austin_outcomes_merged[austin_outcomes_merged['Animal Type']!='Dog']['Animal Type'].unique()
# Out:
# array(['Cat', 'Other', 'Bird', 'Livestock'], dtype=object)

# %%
austin_outcomes_merged[austin_outcomes_merged['Animal Type']!='Dog']
# Out:
#        Animal ID        Name                DateTime MonthYear Date of Birth  \
# 0        A794011       Chunk  05/08/2019 06:20:00 PM  May 2019    05/02/2017
# 2        A821648         NaN  08/16/2020 11:38:00 AM  Aug 2020    08/16/2019
# 4        A674754         NaN  03/18/2014 11:47:00 AM  Mar 2014    03/12/2014
# 7        A689724  *Donatello  10/18/2014 06:52:00 PM  Oct 2014    08/01/2014
# 8        A680969       *Zeus  08/05/2014 04:59:00 PM  Aug 2014    06/03/2014
# ...          ...         ...                     ...       ...           ...
# 136560   A745494     Stanley  04/19/2017 05:54:00 PM  Apr 2017    09/12/2016
# 136561   A745494     Stanley  03/22/2017 05:04:00 PM  Mar 2017    09/12/2016
# 136565   A745494     Stanley  11/09/2021 01:44:00 PM  Nov 2021    09/12/2016
# 136566   A851179        Hops  02/10/2022 01:11:00 PM  Feb 2022    02/08/2021
# 136569   A851181      Mighty  02/10/2022 01:10:00 PM  Feb 2022    02/08/2021
#
# ...

# %%
austin_outcomes_merged[austin_outcomes_merged['Animal Type']!='Dog'].index
# Out:
# Int64Index([     0,      2,      4,      7,      8,     10,     11,     14,
#                 15,     16,
#             ...
#             136550, 136553, 136556, 136557, 136558, 136560, 136561, 136565,
#             136566, 136569],
#            dtype='int64', length=59832)

# %%
austin_outcomes_dogs = austin_outcomes_merged.drop(labels=austin_outcomes_merged[austin_outcomes_merged['Animal Type']!='Dog'].index)

# %%
austin_intakes_dogs['Animal Type'].unique()
# Out:
# array(['Dog'], dtype=object)

# %% [markdown]
# ## austin_animal_data

# %%
#Examine columns in austin_animal_data

austin_animal_data.head(2)
# Out:
#       id     intakedate intakereason  istransfer sheltercode identichipnumber  \
# 0  15801  11/28/09 0:00       Moving           0   C09115463       0A115D7358
# 1  15932   12/8/09 0:00       Moving           0   D09125594       0A11675477
#
#   animalname                breedname basecolour speciesname  ...  \
# 0     Jadzia      Domestic Short Hair     Tortie         Cat  ...
# 1      Gonzo  German Shepherd Dog/Mix        Tan         Dog  ...
#
#    movementdate movementtype istrial returndate returnedreason  deceaseddate  \
# 0  5/13/17 0:00     Adoption     0.0        NaN          Stray           NaN
# 1  4/24/17 0:00     Adoption     0.0        NaN          Stray           NaN
#
#   deceasedreason diedoffshelter puttosleep isdoa
# 0   Died in care              0          0     0
# 1   Died in care              0          0     0
#
# [2 rows x 23 columns]

# %%
# 'speciesname' other than 'Dog' in austin_animal_data

austin_animal_data[austin_animal_data['speciesname']!='Dog']['speciesname'].unique()
# Out:
# array(['Cat', 'House Rabbit', 'Rat', 'Bird', 'Opossum', 'Chicken',
#        'Wildlife', 'Ferret', 'Tortoise', 'Pig', 'Hamster', 'Guinea Pig',
#        'Gerbil', 'Lizard', 'Hedgehog', 'Chinchilla', 'Goat', 'Snake',
#        'Squirrel', 'Sugar Glider', 'Turtle', 'Tarantula', 'Mouse',
#        'Raccoon', 'Livestock', 'Fish'], dtype=object)

# %%
austin_animal_data[austin_animal_data['speciesname']!='Dog']
# Out:
#           id     intakedate           intakereason  istransfer sheltercode  \
# 0      15801  11/28/09 0:00                 Moving           0   C09115463
# 3      30812   1/11/13 0:00              Abandoned           0    C1301091
# 4      30812   1/11/13 0:00              Abandoned           0    C1301091
# 7      40705   6/19/15 0:00              Abandoned           0   R15061738
# 8      40706   6/19/15 0:00              Abandoned           0   R15061739
# ...      ...            ...                    ...         ...         ...
# 10282  64571  8/26/19 16:40       Unable to Afford           0   G19081419
# 10283  64574  8/26/19 16:48  Litter relinquishment           0   C19081422
# 10284  64582  8/27/19 16:12              Allergies           0   C19081427
# 10285  64584  8/27/19 16:52  Litter relinquishment           0   C19081429
# 10286  64588  8/27/19 18:14                  Stray           0   C19081418
#
#       identichipnumber   animalname                breedname  \
# ...

# %%
# indexes with 'speciesname' other than 'Dog' in austin_animal_data

austin_animal_data[austin_animal_data['speciesname']!='Dog'].index
# Out:
# Int64Index([    0,     3,     4,     7,     8,    12,    13,    15,    16,
#                19,
#             ...
#             10276, 10277, 10278, 10280, 10281, 10282, 10283, 10284, 10285,
#             10286],
#            dtype='int64', length=6390)

# %%
# drop rows with 'speciesname' other than 'Dog' from austin_animal_data

austin_animal_data_dogs = austin_animal_data.drop(labels=austin_animal_data[austin_animal_data['speciesname']!='Dog'].index)

# %%
# check that dataframe only contains dogs

austin_animal_data_dogs['speciesname'].unique()
# Out:
# array(['Dog'], dtype=object)

# %% [markdown]
# ## dallas_shelter_data

# %%
# Examine columns of dallas_shelter_data

dallas_shelter_data.head(2)
# Out:
#   Animal Id Animal Type Animal Breed Kennel Number Kennel Status  Tag Type  \
# 0  A1093136         CAT  DOMESTIC SH           K01     IMPOUNDED       NaN
# 1  A1046046         DOG     PIT BULL        AD 085   UNAVAILABLE       NaN
#
#   Activity Number  Activity Sequence Source Id Census Tract  ... Outcome Time  \
# 0             NaN                  1  P0915082         5200  ...     14:46:00
# 1      A19-203263                  1  P0740141        12900  ...     14:56:00
#
#   Receipt Number Impound Number  Service Request Number Outcome Condition  \
# 0            NaN     K20-494003                     NaN          APP SICK
# 1     R19-561166     K19-489088                     NaN           APP WNL
#
#     Chip Status     Animal Origin Additional Information     Month    Year
# 0  SCAN NO CHIP  OVER THE COUNTER                    NaN  JAN.2020  FY2020
# 1     SCAN CHIP             FIELD               ADOPTION  NOV.2019  FY2020
#
# [2 rows x 34 columns]

# %%
# Rows with 'Animal Type' other than 'DOG'

dallas_shelter_data[dallas_shelter_data['Animal Type']!='DOG']['Animal Type'].unique()
# Out:
# array(['CAT', 'BIRD', 'WILDLIFE', 'LIVESTOCK'], dtype=object)

# %%
dallas_shelter_data[dallas_shelter_data['Animal Type']!='DOG']
# Out:
#       Animal Id Animal Type Animal Breed Kennel Number Kennel Status  \
# 0      A1093136         CAT  DOMESTIC SH           K01     IMPOUNDED
# 2      A1098758        BIRD         HAWK     RECEIVING   UNAVAILABLE
# 4      A1091970         CAT  DOMESTIC SH         CC 25   UNAVAILABLE
# 15     A1090539         CAT  DOMESTIC SH           K03     AVAILABLE
# 16     A1090998         CAT  DOMESTIC SH         CC 23   UNAVAILABLE
# ...         ...         ...          ...           ...           ...
# 31892  A1091015    WILDLIFE     SQUIRREL        LAB 01     IMPOUNDED
# 31899  A1091037         CAT  DOMESTIC LH     RECEIVING     IMPOUNDED
# 31901  A1091042         CAT  DOMESTIC SH       LFC 044     AVAILABLE
# 31905  A1091059         CAT  DOMESTIC SH     RECEIVING     IMPOUNDED
# 31906  A1091079         CAT  DOMESTIC MH         VT 07     IMPOUNDED
#
#        Tag Type Activity Number  Activity Sequence Source Id Census Tract  \
# ...

# %%
# Indexes of rows with 'Animal Type' other than 'DOG'

dallas_shelter_data[dallas_shelter_data['Animal Type']!='DOG'].index
# Out:
# Int64Index([    0,     2,     4,    15,    16,    21,    25,    31,    32,
#                38,
#             ...
#             31883, 31886, 31887, 31888, 31891, 31892, 31899, 31901, 31905,
#             31906],
#            dtype='int64', length=9574)

# %%
# Drops rows with 'Animal Type' other than 'DOG'

dallas_shelter_data_dogs = dallas_shelter_data.drop(labels=dallas_shelter_data[dallas_shelter_data['Animal Type']!='DOG'].index)

# %%
# Checkt that df only contains dogs

dallas_shelter_data_dogs['Animal Type'].unique()
# Out:
# array(['DOG'], dtype=object)

# %% [markdown]
# # Check for same animal across intakes and outcomes Dfs based on ID & try to merge

# %% [markdown]
# ## Austin intakes & outcomes

# %%
austin_outcomes_dogs.head(2)
# Out:
#   Animal ID   Name                DateTime MonthYear Date of Birth  \
# 1   A776359  Gizmo  07/18/2018 04:02:00 PM  Jul 2018    07/12/2017
# 3   A720371  Moose  02/13/2016 05:59:00 PM  Feb 2016    10/08/2015
#
#   Outcome Type Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 1     Adoption             NaN         Dog    Neutered Male           1 year
# 3     Adoption             NaN         Dog    Neutered Male         4 months
#
#                                 Breed        Color
# 1             Chihuahua Shorthair Mix  White/Brown
# 3  Anatol Shepherd/Labrador Retriever         Buff

# %%
austin_intakes_dogs.head(2)
# Out:
#   Animal ID    Name                DateTime     MonthYear  \
# 0   A786884  *Brock  01/03/2019 04:19:00 PM  January 2019
# 1   A706918   Belle  07/05/2015 12:59:00 PM     July 2015
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake                     Breed  \
# 0         Dog   Neutered Male         2 years                Beagle Mix
# 1         Dog   Spayed Female         8 years  English Springer Spaniel
#
#          Color
# 0     Tricolor
# 1  White/Liver

# %%
# duplicate Animal IDs in austin intakes
# duplciates appear to be same animal that has gone through intake at the shelter multiple times

austin_intakes_dogs[austin_intakes_dogs['Animal ID'].duplicated(keep=False)==True].sort_values(by='Animal ID').head(10)
# Out:
#        Animal ID    Name                DateTime       MonthYear  \
# 91423    A006100   Scamp  03/07/2014 02:26:00 PM      March 2014
# 20233    A006100   Scamp  12/07/2017 02:07:00 PM   December 2017
# 4344     A006100   Scamp  12/19/2014 10:21:00 AM   December 2014
# 99487    A245945  Boomer  07/03/2014 05:55:00 PM       July 2014
# 122656   A245945  Boomer  05/20/2015 10:34:00 PM        May 2015
# 869      A287017  Stitch  08/16/2015 12:19:00 PM     August 2015
# 119396   A287017  Stitch  12/12/2014 07:04:00 AM   December 2014
# 32534    A307010  Cooper  09/25/2016 12:51:00 PM  September 2016
# 36530    A307010  Cooper  06/01/2017 11:47:00 AM       June 2017
# 57877    A322813   Tyson  03/05/2015 02:49:00 PM      March 2015
#
#                                            Found Location      Intake Type  \
# 91423                        8700 Research in Austin (TX)    Public Assist
# 20233       Colony Creek And Hunters Trace in Austin (TX)            Stray
# ...

# %%
# duplicate Animal IDs in austin outcomes
# duplciates appear to be same animal that has had recorded outcome at the shelter multiple times

austin_outcomes_dogs[austin_outcomes_dogs['Animal ID'].duplicated(keep=False)==True].sort_values(by='Animal ID').head(10)
# Out:
#        Animal ID    Name                DateTime MonthYear Date of Birth  \
# 101494   A006100   Scamp  12/07/2017 12:00:00 AM  Dec 2017    07/09/2007
# 56686    A006100   Scamp  12/20/2014 04:35:00 PM  Dec 2014    07/09/2007
# 115237   A006100   Scamp  03/08/2014 05:10:00 PM  Mar 2014    07/09/2007
# 90697    A245945  Boomer  07/04/2014 03:26:00 PM  Jul 2014    05/23/2000
# 69529    A245945  Boomer  05/25/2015 11:49:00 AM  May 2015    05/23/2000
# 71155    A287017  Stitch  08/16/2015 01:31:00 PM  Aug 2015    05/13/2001
# 24409    A287017  Stitch  12/12/2014 04:49:00 PM  Dec 2014    05/13/2001
# 94844    A307010  Cooper  06/05/2017 03:11:00 PM  Jun 2017    03/04/2003
# 38142    A307010  Cooper  09/28/2016 09:36:00 AM  Sep 2016    03/04/2003
# 53506    A322813   Tyson  12/24/2015 02:31:00 PM  Dec 2015    03/26/2003
#
#            Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 101494  Return to Owner             NaN         Dog    Neutered Male
# ...

# %%
austin_intakes_dogs.shape
# Out:
# (76769, 12)

# %%
austin_outcomes_dogs.shape
# Out:
# (76727, 12)

# %%
# Rows of austin intakes and austin outcomes appear to largely line up, however dates for each animal are not necessarily listed in the same order and intakes has ~40 more rows

# %%
austin_outcomes_dogs.sort_values(by='Animal ID').head()
# Out:
#        Animal ID    Name                DateTime MonthYear Date of Birth  \
# 115237   A006100   Scamp  03/08/2014 05:10:00 PM  Mar 2014    07/09/2007
# 101494   A006100   Scamp  12/07/2017 12:00:00 AM  Dec 2017    07/09/2007
# 56686    A006100   Scamp  12/20/2014 04:35:00 PM  Dec 2014    07/09/2007
# 39142    A047759    Oreo  04/07/2014 03:12:00 PM  Apr 2014    04/02/2004
# 81491    A134067  Bandit  11/16/2013 11:54:00 AM  Nov 2013    10/16/1997
#
#            Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 115237  Return to Owner             NaN         Dog    Neutered Male
# 101494  Return to Owner             NaN         Dog    Neutered Male
# 56686   Return to Owner             NaN         Dog    Neutered Male
# 39142          Transfer         Partner         Dog    Neutered Male
# 81491   Return to Owner             NaN         Dog    Neutered Male
#
#        Age upon Outcome                 Breed         Color
# ...

# %%
austin_intakes_dogs.sort_values(by='Animal ID').head()
# Out:
#       Animal ID    Name                DateTime      MonthYear  \
# 20233   A006100   Scamp  12/07/2017 02:07:00 PM  December 2017
# 91423   A006100   Scamp  03/07/2014 02:26:00 PM     March 2014
# 4344    A006100   Scamp  12/19/2014 10:21:00 AM  December 2014
# 71055   A047759    Oreo  04/02/2014 03:55:00 PM     April 2014
# 96671   A134067  Bandit  11/16/2013 09:02:00 AM  November 2013
#
#                                       Found Location      Intake Type  \
# 20233  Colony Creek And Hunters Trace in Austin (TX)            Stray
# 91423                   8700 Research in Austin (TX)    Public Assist
# 4344               8700 Research Blvd in Austin (TX)    Public Assist
# 71055                                    Austin (TX)  Owner Surrender
# 96671             12034 Research Blvd in Austin (TX)    Public Assist
#
#       Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 20233           Normal         Dog   Neutered Male        10 years
# ...

# %%
# for all unique Animal IDs in austin outcomes, how many are unique to outcomes df (not also seen in intakes df) ?

outcomes_unique_ids = []
for id in list(austin_outcomes_dogs['Animal ID'].drop_duplicates(keep='first')):
    if not id in list(austin_intakes_dogs['Animal ID'].drop_duplicates(keep='first')):
        outcomes_unique_ids.append(id)

# %%
# 381 Animal IDs unique to outcomes df - over 76,000 present in both datasets

len(outcomes_unique_ids)
# Out:
# 381

# %%
austin_intakes_dogs.columns
# Out:
# Index(['Animal ID', 'Name', 'DateTime', 'MonthYear', 'Found Location',
#        'Intake Type', 'Intake Condition', 'Animal Type', 'Sex upon Intake',
#        'Age upon Intake', 'Breed', 'Color'],
#       dtype='object')

# %%
austin_outcomes_dogs.columns
# Out:
# Index(['Animal ID', 'Name', 'DateTime', 'MonthYear', 'Date of Birth',
#        'Outcome Type', 'Outcome Subtype', 'Animal Type', 'Sex upon Outcome',
#        'Age upon Outcome', 'Breed', 'Color'],
#       dtype='object')

# %%
#List of all Animal IDs in austin outcomes and intakes (with duplicates - IDs in both lists not removed)

austin_in_out_ids = list(austin_outcomes_dogs['Animal ID'].drop_duplicates(keep='first')) + list(austin_intakes_dogs['Animal ID'].drop_duplicates(keep='first'))

# %%
# list of all Animal IDs in austin outcomes and intakes without duplicates

austin_in_out_ids_unique = []

for id in austin_in_out_ids:
    if not id in austin_in_out_ids_unique:
        austin_in_out_ids_unique.append(id)

# %%
austin_intakes_dogs['Animal ID'].value_counts().sort_values(ascending=False).head(20)
# Out:
# A721033    33
# A718223    14
# A718877    12
# A706536    11
# A761266     9
# A737814     9
# A717053     9
# A700407     9
# A716018     9
# A616444     9
# A705625     8
# A670937     8
# A738324     8
# A733594     8
# A759467     8
# A693283     8
# A670612     8
# A694501     8
# A738073     8
# A737833     8
# Name: Animal ID, dtype: int64

# %%
austin_intakes_dogs[['DateTime']].head()
# Out:
#                  DateTime
# 0  01/03/2019 04:19:00 PM
# 1  07/05/2015 12:59:00 PM
# 2  04/14/2016 06:43:00 PM
# 4  06/29/2014 10:38:00 AM
# 5  02/18/2017 12:46:00 PM

# %%
pd.to_datetime(austin_intakes_dogs['DateTime'])
# Out:
# 0        2019-01-03 16:19:00
# 1        2015-07-05 12:59:00
# 2        2016-04-14 18:43:00
# 4        2014-06-29 10:38:00
# 5        2017-02-18 12:46:00
#                  ...
# 136280   2022-02-09 15:01:00
# 136282   2022-02-09 15:04:00
# 136283   2022-02-09 15:00:00
# 136285   2022-02-09 15:18:00
# 136287   2022-01-21 17:45:00
# Name: DateTime, Length: 76769, dtype: datetime64[ns]

# %%
austin_intakes_dogs['DateTime'] = pd.to_datetime(austin_intakes_dogs['DateTime'])

# %%
austin_intakes_dogs.sort_values(by='DateTime').head(15)
# Out:
#        Animal ID      Name            DateTime     MonthYear  \
# 72982    A521520      Nina 2013-10-01 07:51:00  October 2013
# 117677   A664233    Stevie 2013-10-01 08:53:00  October 2013
# 4788     A664234       NaN 2013-10-01 10:37:00  October 2013
# 89334    A664257    Pippin 2013-10-01 11:01:00  October 2013
# 24042    A664266       NaN 2013-10-01 11:09:00  October 2013
# 23514    A648744    Claire 2013-10-01 11:15:00  October 2013
# 4903     A664258    Sylvio 2013-10-01 11:15:00  October 2013
# 3477     A651630   Heather 2013-10-01 11:23:00  October 2013
# 7896     A664259  *Petunia 2013-10-01 11:25:00  October 2013
# 119605   A664269  *Bismark 2013-10-01 11:28:00  October 2013
# 43133    A664267     *Asti 2013-10-01 11:59:00  October 2013
# 46947    A664272    *Grace 2013-10-01 13:12:00  October 2013
# 4705     A664273     Buffy 2013-10-01 13:32:00  October 2013
# 29751    A639030      Cate 2013-10-01 13:36:00  October 2013
# ...

# %%
austin_outcomes_dogs['DateTime'] = pd.to_datetime(austin_outcomes_dogs['DateTime'])
# Out:
# /var/folders/4l/vc1t1v4j7qd0h8x2x8dt42rw0000gn/T/ipykernel_5084/677630372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   austin_outcomes_dogs['DateTime'] = pd.to_datetime(austin_outcomes_dogs['DateTime'])

# %% [markdown]
# ### Create list of dictionaries with data for each animal including ID, name, breed, color, date of birth, intake(s) information, & outcome(s) information

# %% [markdown]
# #### Test for one Animal ID

# %%
test_austin_animals = []

# %%
id = 'A006100'

# %%
###create animal dictionary###
test_id_dict = {}

# %%
###fill in basics of animal dictionary###

# %%
# find intake rows containing animal
if id in list(austin_intakes_dogs['Animal ID'].drop_duplicates(keep='first')):
    test_id_intakes_row = austin_intakes_dogs[austin_intakes_dogs['Animal ID']==id]

test_id_intakes_row
# Out:
#       Animal ID   Name            DateTime      MonthYear  \
# 4344    A006100  Scamp 2014-12-19 10:21:00  December 2014
# 20233   A006100  Scamp 2017-12-07 14:07:00  December 2017
# 91423   A006100  Scamp 2014-03-07 14:26:00     March 2014
#
#                                       Found Location    Intake Type  \
# 4344               8700 Research Blvd in Austin (TX)  Public Assist
# 20233  Colony Creek And Hunters Trace in Austin (TX)          Stray
# 91423                   8700 Research in Austin (TX)  Public Assist
#
#       Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 4344            Normal         Dog   Neutered Male         7 years
# 20233           Normal         Dog   Neutered Male        10 years
# 91423           Normal         Dog   Neutered Male         6 years
#
#                       Breed         Color
# 4344   Spinone Italiano Mix  Yellow/White
# 20233  Spinone Italiano Mix  Yellow/White
# 91423  Spinone Italiano Mix  Yellow/White

# %%
#find outcome rows containing animal
if id in list(austin_outcomes_dogs['Animal ID'].drop_duplicates(keep='first')):
    test_id_outcomes_row = austin_outcomes_dogs[austin_outcomes_dogs['Animal ID']==id]

test_id_outcomes_row
# Out:
#        Animal ID   Name            DateTime MonthYear Date of Birth  \
# 56686    A006100  Scamp 2014-12-20 16:35:00  Dec 2014    07/09/2007
# 101494   A006100  Scamp 2017-12-07 00:00:00  Dec 2017    07/09/2007
# 115237   A006100  Scamp 2014-03-08 17:10:00  Mar 2014    07/09/2007
#
#            Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 56686   Return to Owner             NaN         Dog    Neutered Male
# 101494  Return to Owner             NaN         Dog    Neutered Male
# 115237  Return to Owner             NaN         Dog    Neutered Male
#
#        Age upon Outcome                 Breed         Color
# 56686           7 years  Spinone Italiano Mix  Yellow/White
# 101494         10 years  Spinone Italiano Mix  Yellow/White
# 115237          6 years  Spinone Italiano Mix  Yellow/White

# %%
# isolate one intake row to get basic info from
if len(test_id_intakes_row) > 1:
    test_id_intakes_row = test_id_intakes_row.iloc[[0]]

test_id_intakes_row
# Out:
#      Animal ID   Name            DateTime      MonthYear  \
# 4344   A006100  Scamp 2014-12-19 10:21:00  December 2014
#
#                          Found Location    Intake Type Intake Condition  \
# 4344  8700 Research Blvd in Austin (TX)  Public Assist           Normal
#
#      Animal Type Sex upon Intake Age upon Intake                 Breed  \
# 4344         Dog   Neutered Male         7 years  Spinone Italiano Mix
#
#              Color
# 4344  Yellow/White

# %%
# isolate one outcome row to get basic info from
if len(test_id_outcomes_row) > 1:
    test_id_outcomes_row = test_id_outcomes_row.iloc[[0]]

test_id_outcomes_row
# Out:
#       Animal ID   Name            DateTime MonthYear Date of Birth  \
# 56686   A006100  Scamp 2014-12-20 16:35:00  Dec 2014    07/09/2007
#
#           Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 56686  Return to Owner             NaN         Dog    Neutered Male
#
#       Age upon Outcome                 Breed         Color
# 56686          7 years  Spinone Italiano Mix  Yellow/White

# %%
# Add ID, name, breed, color, & DOB to animal dictionary using intake row
test_id_dict['id'] = id
if id in list(austin_intakes_dogs['Animal ID'].drop_duplicates(keep='first')):
    test_id_dict['name'] = test_id_intakes_row['Name']
    test_id_dict['breed'] = test_id_intakes_row['Breed']
    test_id_dict['color'] = test_id_intakes_row['Color']
    test_id_dict['dob'] = 'unknown'

test_id_dict
# Out:
# {'id': 'A006100',
#  'name': 4344    Scamp
#  Name: Name, dtype: object,
#  'breed': 4344    Spinone Italiano Mix
#  Name: Breed, dtype: object,
#  'color': 4344    Yellow/White
#  Name: Color, dtype: object,
#  'dob': 'unknown'}

# %%
# Update ID, name, breed, color, & DOB in animal dictionary using outcome row
if id in list(austin_outcomes_dogs['Animal ID'].drop_duplicates(keep='first')):
    test_id_dict['name'] = test_id_outcomes_row['Name']
    test_id_dict['breed'] = test_id_outcomes_row['Breed']
    test_id_dict['color'] = test_id_outcomes_row['Color']
    test_id_dict['dob'] = test_id_outcomes_row['Date of Birth']

test_id_dict
# Out:
# {'id': 'A006100',
#  'name': 56686    Scamp
#  Name: Name, dtype: object,
#  'breed': 56686    Spinone Italiano Mix
#  Name: Breed, dtype: object,
#  'color': 56686    Yellow/White
#  Name: Color, dtype: object,
#  'dob': 56686    07/09/2007
#  Name: Date of Birth, dtype: object}

# %%
# if id in list(austin_outcomes_dogs['Animal ID'].drop_duplicates(keep='first')):
#     id_dict['name'] = id_outcomes_row['Name']
#     id_dict['breed'] = id_outcomes_row['Breed']
#     id_dict['color'] = id_outcomes_row['Color']
#     id_dict['dob'] = id_outcomes_row['Date of Birth']
# print('basic info added')

# # Add intake(s) to animal dictionary
# if id in list(austin_intakes_dogs['Animal ID'].drop_duplicates(keep='first')):
#     id_intakes = austin_intakes_dogs[austin_intakes_dogs['Animal ID']==id].sort_values(by='DateTime')
#     number_of_intakes = len(id_intakes)
#     if number_of_intakes==1:
#         id_dict['intake'] = [
#             id_intakes['DateTime'], 
#             id_intakes['Found Location'], 
#             f'{id_intakes["Intake Type"]} - {id_intakes["Intake Condition"]}',
#             id_intakes['Sex upon Intake'],
#             id_intakes['Age upon Intake']
#         ]
#         print('one intake added')
#     else:
#         for i in range(number_of_intakes):
#             id_dict['intakes'][i] = [
#             id_intakes['DateTime'], 
#             id_intakes['Found Location'], 
#             f'{id_intakes["Intake Type"]} - {id_intakes["Intake Condition"]}',
#             id_intakes['Sex upon Intake'],
#             id_intakes['Age upon Intake']
#             ]
#         print('multiple intakes added')
# Out:
# intake rows found
# outcome rows found
# intake row found
# outcome row found
# basic info started
# {'id': 'A006100', 'name': 'Scamp', 'breed': 'Spinone Italiano Mix', 'color': 'Yellow/White', 'dob': 'unknown'}
# basic info added
# intakes dict added
# multiple intakes added

# %%
a = 1

# %%
f'apple_{a}'

# %% [markdown]
# ## Dallas data

# %%
dallas_shelter_data_dogs.head(2)
# Out:
#   Animal Id Animal Type   Animal Breed Kennel Number Kennel Status  Tag Type  \
# 1  A1046046         DOG       PIT BULL        AD 085   UNAVAILABLE       NaN
# 3  A1061310         DOG  LABRADOR RETR       LFD 163   UNAVAILABLE       NaN
#
#   Activity Number  Activity Sequence Source Id Census Tract  ... Outcome Time  \
# 1      A19-203263                  1  P0740141        12900  ...     14:56:00
# 3      A19-206245                  1  P9991730         4800  ...     13:33:00
#
#   Receipt Number Impound Number  Service Request Number Outcome Condition  \
# 1     R19-561166     K19-489088                     NaN           APP WNL
# 3     R19-561090     K19-491175                     NaN           APP WNL
#
#   Chip Status Animal Origin Additional Information     Month    Year
# 1   SCAN CHIP         FIELD               ADOPTION  NOV.2019  FY2020
# 3   SCAN CHIP         FIELD                    NaN  DEC.2019  FY2020
#
# [2 rows x 34 columns]

# %% [markdown]
# # Clean & merge all dataframes
